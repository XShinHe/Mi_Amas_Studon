# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

a=np.array([2,
0.054194,
10,
0.121972,
100,
0.140146,
200,
0.140434,
400,
0.140371,
800,
0.140223,
1000,
0.140604,
2000,
0.140323,
4000,
0.140456,
8000,
0.140359])
a=a.reshape(-1,2).T
plt.plot(np.log10(a[0]),a[1],'r.--')
plt.ylabel(r'$U_{md}$   of   $\frac{1}{4}x^4$')
plt.xlabel(r'$Log(N_{bead})$')
plt.title('potential energy plot with beads')
plt.savefig('xxx.png')
plt.show()
